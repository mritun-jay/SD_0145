# %% [markdown]
# <a href="https://colab.research.google.com/github/mritun-jay/SD_0145/blob/main/Loop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,2,3,4,45,5]
l1=[]
for i in l :
  l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
[i**2 for i in l]
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
[i for i in l if i % 2 ==0]
# Out:
# [2, 4]

# %%
l1 = ["sudha" , "skills" , "kumar" , "data science"]

# %%
[i.upper() for i in l1]
# Out:
# ['SUDHA', 'SKILLS', 'KUMAR', 'DATA SCIENCE']

# %%
l
# Out:
# [1, 2, 3, 4, 45, 5]

# %%
list(i**2 for i in l)
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
d ={"key1" :1 , "key2" :2 , "key3" :3 , "key4" :4}

# %%
{k:v**2 for k , v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %%
{k : v for k , v in d.items() if v >1}
# Out:
# {'key2': 2, 'key3': 3, 'key4': 4}
