# %% [markdown]
# <a href="https://colab.research.google.com/github/mritun-jay/SD_0145/blob/main/LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X = 4

# %%
X
# Out:
# 4

# %%
NUMS = [1,2,3,4]

# %%
type(NUMS)
# Out:
# list

# %%
NUMS[0]
# Out:
# 1

# %%
NUMS[1]
# Out:
# 2

# %%
NUMS[2]
# Out:
# 3

# %%
NUMS[3]
# Out:
# 4

# %%
NUMS[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_609/2886041085.py in <cell line: 0>()
# ----> 1 NUMS[4]
#
# IndexError: list index out of range

# %%
l =[1,345,45,"sudh",True,5+7j,345.456]

# %%
l[3][0:2]
# Out:
# 'su'

# %%
l[5].real
# Out:
# 5.0

# %%
l[::2]
# Out:
# [1, 45, True, 345.456]

# %%
l[0:3]
# Out:
# [1, 345, 45]

# %%
l[-1]
# Out:
# 345.456

# %%
 l[-1:-5:-2]
# Out:
# [345.456, True]

# %%
l[-1:-6:-2]
# Out:
# [345.456, True, 45]

# %%
l[1:-6:-2]
# Out:
# []

# %%
l.append(7)

# %%
l[7]
# Out:
# 7

# %%
s="abcdefghijklnmopqrshbevbgefbjiaigwydt"

# %%
n+s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1665/1193748072.py in <cell line: 0>()
# ----> 1 n+s
#
# NameError: name 'n' is not defined

# %%
list(s)+l
# Out:
# ['a',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'j',
#  'k',
#  'l',
#  'n',
#  'm',
#  'o',
#  'p',
#  'q',
#  'r',
#  's',
#  'h',
#  'b',
#  'e',
#  'v',
#  'b',
#  'g',
#  'e',
#  'f',
#  'b',
#  'j',
#  'i',
#  'a',
#  'i',
#  'g',
#  'w',
#  'y',
#  'd',
#  't',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  7,
#  7]

# %%
l1 =[12,65,93,True,7]

# %%
l1.append(77)

# %%
l1.pop(7)
# Out:
# 1

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l.insert(2,77)

# %%
l[2]
# Out:
# 77

# %%
x = "10"

# %%
y = int(x)

# %%
print(y)
# Out:
# 10

# %%
x = "3.14"

# %%
y = float(x)

# %%
print(y)
# Out:
# 3.14

# %%
x = 25

# %%
y = str(x)

# %%
print(y)
# Out:
# 25

# %%
x = (1,2,3)

# %%
y = list(x)

# %%
print(y)
# Out:
# [1, 2, 3]

# %%
x = [1,2,3]

# %%
y = tuple(x)

# %%
print(y)
# Out:
# (1, 2, 3)

# %%
x = [1,2,2,3]

# %%
y = set(x)

# %%
print(y)
# Out:
# {1, 2, 3}
