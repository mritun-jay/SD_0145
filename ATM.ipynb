# %% [markdown]
# <a href="https://colab.research.google.com/github/mritun-jay/SD_0145/blob/main/ATM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
card=input("enter the card no")
withdrawl=int(input("enter the amount withdrawl"))
checkbalance=int(input("enter the checkbalance"))
transation=int(input("enter the transation"))
cashandcheckdepoist=int(input("enter the cash and checkdepoist"))
pinchange=int(input("enter the pinchange"))
ministatement=int(input("enter the ministatement"))
pin=int(input("enter the pin no"))
amount=int(input("enter the amount"))
balance=int(input("enter the balance"))
# Out:
# enter the card no123456781234
# enter the amount withdrawl1
# enter the checkbalance2
# enter the transation3
# enter the cash and checkdepoist4
# enter the pinchange5
# enter the ministatement7
# enter the pin no6
# enter the amount1000
# enter the balance1000000

# %%
  services=int(input("enter the services"))
  if(services==1):
    print("withdrawl")
  elif(services==2):
    print("checkbalance")
  elif(services==3):
    print("transiton")
  elif(services==4):
    print("cashandcheckdepoist")
  elif(services==5):
    print("pinchange")
  elif(services==7):
    print("ministatement")

  if balance>amount:
      balance = balance - amount
      print("withdrawl successful")
      print("remaining balance=", balance)
  else:
      print("insufficient balance")
      print("thank you")
# Out:
# enter the services2
# checkbalance
# withdrawl successful
# remaining balance= 999000
