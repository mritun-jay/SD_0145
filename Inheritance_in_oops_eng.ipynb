# %% [markdown]
# <a href="https://colab.research.google.com/github/mritun-jay/SD_0145/blob/main/Inheritance_in_oops_eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class parent:

    def test_parent(self) :
        print("this is my parent class")

# %%
class child(parent):
  pass

# %%
child_obj = child()

# %%
child_obj.test_parent()
# Out:
# this is my parent class

# %%
class class1 :
    def test_class1(self) :
        print("this is my class1")

# %%
class class2(class1) :
    def test_class2(self) :
        print("this is my class2")

# %%
class class3(class2) :
    def test_class3(self) :
        print("this is my class3")

# %%
obj_class3 = class3()

# %%
obj_class3.test_class1()
# Out:
# this is my class1

# %%
obj_class3.test_class2()
# Out:
# this is my class2

# %%
obj_class3.test_class3()
# Out:
# this is my class3

# %%
class class1 :
    def test_class1(self) :
        print("this is my class1")

# %%
class class2:
    def test_class2(self) :
        print("this is my class2")

# %%
class class3(class1, class2) :
    pass
