# %% [markdown]
# <a href="https://colab.research.google.com/github/mritun-jay/SD_0145/blob/main/Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,2,3,4,4,"sudh","kumar",324,34.456,"abc"]

# %%
l1_num = []
l2_str = []
for i in l :
  if type(i) == int or type(i) == float :
      l1_num.append(i)
  else :
      l2_str.append(i)

# %%
text = input("enter a string or number")

if text == text[::-1]:
     print("palindrome")
else:
     print("not a palindrome")
# Out:
# enter a string or number12344321
# palindrome

# %%
x = int(input("enter a number"))
temp  = x
reverse = 0
while x>0:
  digit = x%10
  reverse = (reverse*10)+digit
  x = x/10
if temp == reverse:
  print(temp,"is a palindrome")
else:
  print(temp,"is not a palindrome")
# Out:
# enter a number0
# 0 is a palindrome

# %%
l = [5,9,6,7,8,9,2,3,18,19]

# %%
total = 0
for i in l :
  total = total + i

# %%
print(total)
# Out:
# 86

# %%
dict1 = {'a': 'akshat','b':'bhuvan','c':'chnadra'}

keys = []
values = []
for item in dict1.items():
  keys.append(item[0]), values.append(item[1])

print("keys : ", keys)
print("values :", values)
# Out:
# keys :  ['a', 'b', 'c']
# values : ['akshat', 'bhuvan', 'chnadra']
