# %% [markdown]
# <a href="https://colab.research.google.com/github/mritun-jay/SD_0145/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test():
    pass

# %%
def test1():
    print("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
test1()+ "sudh"
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1637/1705551427.py in <cell line: 0>()
# ----> 1 test1()+ "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
    return "this is my very first return"

# %%
test2()
# Out:
# 'this is my very first return'

# %%
test2() + "sudh"
# Out:
# 'this is my very first returnsudh'

# %%
def test3() :

    return "sudh" , 23 , 345.56 , [1,2,3,3]

# %%
test3()
# Out:
# ('sudh', 23, 345.56, [1, 2, 3, 3])

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 345.56

# %%
d
# Out:
# [1, 2, 3, 3]

# %%
type(test3)
# Out:
# function

# %%
a=1
b=4

# %%
a,b =1,4

# %%
def add():
    a= 5+6/7
    return a

# %%
add()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
    d = a+b/c
    return d

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
test5(2,5,8 )
# Out:
# 2.625

# %%
def test6(a,b):
    return a+b

# %%
test6(3,4)
# Out:
# 7

# %%
test6("sudh","kumar")
# Out:
# 'sudhkumar'

# %%
test6((2,3,4),(9,8,7))
# Out:
# (2, 3, 4, 9, 8, 7)

# %%
test6(["hellow" , 67.88 ,], [587.89,True])
# Out:
# ['hellow', 67.88, 587.89, True]

# %%
def test11(*args):
    return args+ (1,2,3,4)

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3, 1, 2, 3, 4)

# %%
def test17(*kwargs):
    return kwargs+ (1,2,3,4)

# %%
type(test17())
# Out:
# tuple

# %%
test17(1,2,3,4)
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)

# %%
test17(1,2,3,"sudh","kumar",[1,2,3,4])
# Out:
# (1, 2, 3, 'sudh', 'kumar', [1, 2, 3, 4], 1, 2, 3, 4)

# %%
def test12(*sudh):
    return sudh

# %%
test12(1,2,24,4)
# Out:
# (1, 2, 24, 4)

# %%
def test13(*args , a):
    return args , a

# %%
test13(1,2,3,4, a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test14(c,d,a = 23, b=1):
    return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1637/3076521518.py in <cell line: 0>()
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(c,d)
# Out:
# (23, 1, 345.56, [1, 2, 3, 3])

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5, a=2342)
# Out:
# (2342, 1, 2, 5)

# %%
def test15(**kwargs):
    return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="sudh",c=23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}

# %%
def add(a,b):
  return a+b
def sub(a,b):
   return a-b
